# %%
import numpy as np
import pandas as pd
import seaborn as sb
import os

# %%
print(os.listdir())
# Out:
# ['.conda', '.condarc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.nbi', '.oracle_jre_usage', '.pgAdmin4.1057243102.addr', '.pgAdmin4.1057243102.log', '.pgAdmin4.startup.log', '.QtWebEngineProcess', '.VirtualBox', '.Wondershare Filmora9', '1960382_Lab5_DA.ipynb', '3D Objects', 'ageingdetector.ipynb', 'anaconda3', 'ansel', 'AppData', 'Application Data', 'bluej', 'CardioGoodFitness.csv', 'Contacts', 'Cookies', 'Creative Cloud Files', 'DAA_Lab3_1960382.ipynb', 'data.csv', 'DataAnalyticsLab_Exp1.ipynb', 'DataAnalyticsLab_Exp2.ipynb', 'DataCoSupplyChainDataset.csv', 'DataSciences1_Python.ipynb', 'Data_ WFP Coronavirus COVID-19 Travel Restrictions - COVID-19 airline restrictions information.csv', 'deliveries.csv', 'Desktop', 'Documents', 'Downloads', 'edb_psqlodbc.exe', 'Favorites', 'First', 'First-copy', 'Indian Premier League.zip', 'IntelGraphicsProfiles', 'Lab1A_1960382_DAA.ipynb', 'Lab1B_1960382_DAA.ipynb', 'Lab2_1960382_DAA.ipynb', 'LAB3_1960382_DA.ipynb', 'Lab4_DA_
# ...

# %%
df = pd.read_csv("DataCoSupplyChainDataset.csv",encoding="ANSI")

# %%
df
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 0          DEBIT                         3                              4
# 1       TRANSFER                         5                              4
# 2           CASH                         4                              4
# 3          DEBIT                         3                              4
# 4        PAYMENT                         2                              4
# ...          ...                       ...                            ...
# 180514      CASH                         4                              4
# 180515     DEBIT                         3                              2
# 180516  TRANSFER                         5                              4
# 180517   PAYMENT                         3                              4
# 180518   PAYMENT                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.isnull().sum()
# Out:
# Type                                  0
# Days for shipping (real)              0
# Days for shipment (scheduled)         0
# Benefit per order                     0
# Sales per customer                    0
# Delivery Status                       0
# Late_delivery_risk                    0
# Category Id                           0
# Category Name                         0
# Customer City                         0
# Customer Country                      0
# Customer Email                        0
# Customer Fname                        0
# Customer Id                           0
# Customer Lname                        8
# Customer Password                     0
# Customer Segment                      0
# Customer State                        0
# Customer Street                       0
# Customer Zipcode                      3
# Department Id                         0
# Department Name                       0
# Latitude                              0
# ...

# %%
df.describe()
# Out:
#        Days for shipping (real)  Days for shipment (scheduled)  \
# count             180519.000000                  180519.000000
# mean                   3.497654                       2.931847
# std                    1.623722                       1.374449
# min                    0.000000                       0.000000
# 25%                    2.000000                       2.000000
# 50%                    3.000000                       4.000000
# 75%                    5.000000                       4.000000
# max                    6.000000                       4.000000
#
#        Benefit per order  Sales per customer  Late_delivery_risk  \
# count      180519.000000       180519.000000       180519.000000
# mean           21.974989          183.107609            0.548291
# std           104.433526          120.043670            0.497664
# min         -4274.979980            7.490000            0.000000
# 25%             7.000000          104.379997            0.000000
# ...

# %%
df['Product Description'] = df['Product Description'].replace(np.nan,'Unknown')

# %%
df['Order Zipcode'] = df['Order Zipcode'].replace(np.nan,0)

# %%
df.isnull().sum()
# Out:
# Type                             0
# Days for shipping (real)         0
# Days for shipment (scheduled)    0
# Benefit per order                0
# Sales per customer               0
# Delivery Status                  0
# Late_delivery_risk               0
# Category Id                      0
# Category Name                    0
# Customer City                    0
# Customer Country                 0
# Customer Email                   0
# Customer Fname                   0
# Customer Id                      0
# Customer Lname                   0
# Customer Password                0
# Customer Segment                 0
# Customer State                   0
# Customer Street                  0
# Customer Zipcode                 0
# Department Id                    0
# Department Name                  0
# Latitude                         0
# Longitude                        0
# Market                           0
# Order City                       0
# Order Country                    0
# ...

# %%
query1 = (df['Order Country'] == 'India') & (df['Order Status'] == 'PENDING')

# %%
df.loc[query1,'Order City']
# Out:
# 1             Bikaner
# 21           Jabalpur
# 45          Bangalore
# 46          Bangalore
# 382              Pune
#              ...
# 180142    Bhubaneswar
# 180164           Agra
# 180248          Dewas
# 180331          Ajmer
# 180405          Patna
# Name: Order City, Length: 537, dtype: object

# %%
query2 = df['Order Status'] == 'SUSPECTED_FRAUD'

# %%
df.loc[query2, 'Order Country'].mode()
# Out:
# 0    Estados Unidos
# dtype: object

# %%
column = df["Order Item Discount Rate"]

# %%
max_value = column.max()

# %%
max_value
# Out:
# 0.25

# %%
query3 = df['Order Item Discount Rate'] == max_value

# %%
df[query3]
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 13         DEBIT                         2                              1
# 31         DEBIT                         5                              4
# 65       PAYMENT                         6                              2
# 72       PAYMENT                         3                              2
# 111     TRANSFER                         4                              4
# ...          ...                       ...                            ...
# 180441     DEBIT                         2                              1
# 180459     DEBIT                         6                              4
# 180477     DEBIT                         2                              4
# 180495   PAYMENT                         3                              4
# 180513   PAYMENT                         3                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.loc[query3, 'Product Name']
# Out:
# 13                                         Smart watch
# 31                                         Smart watch
# 65                    Nike Men's Free 5.0+ Running Shoe
# 72                 Nike Men's Dri-FIT Victory Golf Polo
# 111       Under Armour Girls' Toddler Spine Surge Runni
#                               ...
# 180441        Field & Stream Sportsman 16 Gun Fire Safe
# 180459        Field & Stream Sportsman 16 Gun Fire Safe
# 180477        Field & Stream Sportsman 16 Gun Fire Safe
# 180495        Field & Stream Sportsman 16 Gun Fire Safe
# 180513        Field & Stream Sportsman 16 Gun Fire Safe
# Name: Product Name, Length: 10029, dtype: object

# %%
query5 = (df['Order Status'] == 'COMPLETE')& (df['Days for shipping (real)'] > df['Days for shipment (scheduled)'])

# %%
df.loc[query5]
# Out:
#          Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 6       DEBIT                         2                              1
# 13      DEBIT                         2                              1
# 15      DEBIT                         2                              1
# 18      DEBIT                         2                              1
# 25      DEBIT                         6                              2
# ...       ...                       ...                            ...
# 180479  DEBIT                         6                              4
# 180499  DEBIT                         4                              2
# 180508  DEBIT                         4                              2
# 180512  DEBIT                         6                              4
# 180515  DEBIT                         3                              2
#
#         Benefit per order  Sales per customer Delivery Status  \
# ...

# %%
df['Product Name'] = df['Product Name'].str[:4]

# %%
query4 = df['Product Name'] == 'Nike'

# %%
df.loc[query4]
# Out:
#             Type  Days for shipping (real)  Days for shipment (scheduled)  \
# 50       PAYMENT                         6                              2
# 52       PAYMENT                         3                              2
# 53       PAYMENT                         5                              2
# 54       PAYMENT                         6                              2
# 59       PAYMENT                         2                              2
# ...          ...                       ...                            ...
# 179604  TRANSFER                         5                              4
# 179605  TRANSFER                         2                              4
# 179606  TRANSFER                         3                              4
# 179607  TRANSFER                         5                              4
# 179608  TRANSFER                         4                              4
#
#         Benefit per order  Sales per customer   Delivery Status  \
# ...

# %%
df.loc[query4, 'order date (DateOrders)']
# Out:
# 50          3/30/2016 4:37
# 52         11/28/2016 1:18
# 53        12/31/2016 15:47
# 54         10/25/2015 6:24
# 59         10/4/2016 22:55
#                 ...
# 179604      3/31/2017 1:39
# 179605      2/10/2017 6:27
# 179606      6/13/2017 2:57
# 179607      4/14/2015 5:59
# 179608     1/18/2015 11:21
# Name: order date (DateOrders), Length: 57309, dtype: object

# %%
df["order date (DateOrders)"] = pd.to_datetime(df["order date (DateOrders)"])

# %%
df["order date (DateOrders)"].dt.year.value_counts()
# Out:
# 2015    62650
# 2016    62550
# 2017    53196
# 2018     2123
# Name: order date (DateOrders), dtype: int64
